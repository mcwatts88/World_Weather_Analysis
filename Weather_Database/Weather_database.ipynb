# %%
# Import dependencies

import pandas as pd

import numpy as np

from citipy import citipy

import requests

import sys

sys.path.append('../../API_keys')

from config import weather_api_key

import time

# %%
# Generate 2000 random latitudes and longitudes

lats = np.random.uniform(low=-90.000, high=90.000, size=2000)

lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

lat_lngs = zip(lats, lngs)

coordinates = list(lat_lngs)

# %%
# Identify the closest city for each coordinate pair

cities = []

for coordinate in coordinates:
    
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    if city not in cities:
        
        cities.append(city)
        
len(cities)
# Out:
# 748

# %%
cities
# Out:
# ['meyungs',
#  'fuerte olimpo',
#  'barrow',
#  'rikitea',
#  'kodiak',
#  'verkhoyansk',
#  'vaitupu',
#  'hermanus',
#  'bluff',
#  'margate',
#  'skagastrond',
#  'taolanaro',
#  'provideniya',
#  'pangnirtung',
#  'punta arenas',
#  'carnarvon',
#  'east london',
#  'ugoofaaru',
#  'vaini',
#  'celestun',
#  'hithadhoo',
#  'tiksi',
#  'galveston',
#  'formosa do rio preto',
#  'aksarka',
#  'bredasdorp',
#  'yamada',
#  'ushuaia',
#  'sayat',
#  'kavieng',
#  'mandurah',
#  'belushya guba',
#  'ormara',
#  'upernavik',
#  'port lincoln',
#  'nikolskoye',
#  'kapaa',
#  'nizhneyansk',
#  'new norfolk',
#  'hasaki',
#  'yatou',
#  'buala',
#  'palabuhanratu',
#  'chokurdakh',
#  'avarua',
#  'marawi',
#  'sangmelima',
#  'illoqqortoormiut',
#  'lompoc',
#  'san carlos de bariloche',
#  'dikson',
#  'frontera hidalgo',
#  'busselton',
#  'kharp',
#  'grand river south east',
#  'puerto ayora',
#  'port elizabeth',
#  'ribeira grande',
#  'faanui',
#  'bolungarvik',
#  'saint george',
#  'barentsburg',
#  'mataura',
#  'qaanaaq',
#  'atuona',
#  'longyearbyen',
#  'nome',
#  'ponta do sol',
#  'souillac',
#  'borogontsy',
#  'cidreira',
#  'coahuayana',
#  'mbandaka',
#  'albany',
#  'dingle',
#  'champerico',
#  'saskylakh',
#  'clarksburg',
#  'samalaeulu',
#  'balakhninskiy',
#  'sur',
#  'atlantic beach',
#  'hobyo',
#  'tuktoyaktuk',
#  'sisimiut',
#  'nguiu',
#  'price',
#  'khatanga',
#  'victor harbor',
#  'tsogni',
#  'ust-maya',
#  'tigil',
#  'takestan',
#  'jamestown',
#  'mugur-aksy',
#  'kang',
#  'chuy',
#  'mariano escobedo',
#  'port hardy',
#  'saint-augustin',
#  'krasnoselkup',
#  'bandarbeyla',
#  'bethel',
#  'ostrovnoy',
#  'castro',
#  'luderitz',
#  'neon karlovasion',
#  'kaitangata',
#  'mahebourg',
#  'khartoum',
#  'betare oya',
#  'houma',
#  'bairiki',
#  'keningau',
#  'klaksvik',
#  'moose factory',
#  'ararat',
#  'culebra',
#  'tsihombe',
#  'hobart',
#  'leopold',
#  'port alfred',
#  'mrirt',
#  'berezovyy',
#  'erenhot',
#  'la romana',
#  'hilo',
#  'terrak',
#  'rock sound',
#  'canon city',
#  'ziarat',
#  'agadez',
#  'zheleznodorozhnyy',
#  'aklavik',
#  'bangassou',
#  'cape town',
#  'westport',
#  'modakeke',
#  'kimbe',
#  'tautira',
#  'saint anthony',
#  'tasiilaq',
#  'aden',
#  'merthyr tydfil',
#  'tomatlan',
#  'te anau',
#  'lagoa',
#  'lethem',
#  'namatanai',
#  'inirida',
#  'esperance',
#  'severo-kurilsk',
#  'lichinga',
#  'lebu',
#  'padron',
#  'saint-georges',
#  'ayan',
#  'salalah',
#  'nioro',
#  'port-gentil',
#  'rio de janeiro',
#  'kallithea',
#  'georgetown',
#  'kamenskoye',
#  'fortuna',
#  'presidencia roque saenz pena',
#  'cumaribo',
#  'magadan',
#  'husavik',
#  'tambura',
#  'brae',
#  'port hawkesbury',
#  'antofagasta',
#  'saldanha',
#  'garowe',
#  'banmo',
#  'zarichne',
#  'port blair',
#  'stepnogorsk',
#  'sitka',
#  'iquique',
#  'merauke',
#  'atar',
#  'meulaboh',
#  'kloulklubed',
#  'butaritari',
#  'srednekolymsk',
#  'mar del plata',
#  'maniitsoq',
#  'rundu',
#  'lyubim',
#  'nuuk',
#  'axim',
#  'cururupu',
#  'along',
#  'tumannyy',
#  'socorro',
#  'iracoubo',
#  'narsaq',
#  'urusha',
#  'tawnat',
#  'alekseyevka',
#  'naze',
#  'vila franca do campo',
#  'mersing',
#  'makushino',
#  'haines junction',
#  'balkhash',
#  'ancud',
#  'nemuro',
#  'mingshui',
#  'abu samrah',
#  'westpunt',
#  'taltal',
#  'coihaique',
#  'oistins',
#  'clarence town',
#  'sao gabriel da cachoeira',
#  'jibuti',
#  'hami',
#  'mitzic',
#  'lasa',
#  'lorengau',
#  'nouakchott',
#  'saleaula',
#  'lucea',
#  'qabis',
#  'pacora',
#  'iskateley',
#  'robertsport',
#  'bintulu',
#  'marinette',
#  'hervey bay',
#  'isangel',
#  'lata',
#  'iqaluit',
#  'abu kamal',
#  'thompson',
#  'belaya gora',
#  'naryan-mar',
#  'khipro',
#  'sahrak',
#  'pizhma',
#  'adre',
#  'cabo san lucas',
#  'arraial do cabo',
#  'pevek',
#  'shubarshi',
#  'hihifo',
#  'saint-pierre',
#  'mys shmidta',
#  'gilgit',
#  'yerbogachen',
#  'hare bay',
#  'ahipara',
#  'clyde river',
#  'hay river',
#  'togur',
#  'airai',
#  'arrifes',
#  'grand centre',
#  'san policarpo',
#  'oga',
#  'genhe',
#  'codrington',
#  'mattru',
#  'taranagar',
#  'katangli',
#  'otradnoye',
#  'tura',
#  'skibbereen',
#  'bambous virieux',
#  'fukue',
#  'pisco',
#  'mosetse',
#  'batemans bay',
#  'bilma',
#  'marrakesh',
#  'tarko-sale',
#  'tuatapere',
#  'areosa',
#  'benghazi',
#  'ust-kamchatsk',
#  'temaraia',
#  'cheuskiny',
#  'kadykchan',
#  'morant bay',
#  'letka',
#  'katobu',
#  'torbay',
#  'jinchengjiang',
#  'namibe',
#  'mayo',
#  'chino',
#  'hunsur',
#  'fort saint john',
#  'hobbs',
#  'asfi',
#  'barbate',
#  'dargaville',
#  'ambon',
#  'lannion',
#  'vanersborg',
#  'leningradskiy',
#  'raymondville',
#  'sorong',
#  'korla',
#  'asau',
#  'zhengjiatun',
#  'klyuchi',
#  'saint-philippe',
#  'lugovoy',
#  'yellowknife',
#  'tam ky',
#  'samfya',
#  'novo aripuana',
#  'jati',
#  'najran',
#  'penzance',
#  'ypsonas',
#  'nishihara',
#  'nanortalik',
#  'maumere',
#  'kalomo',
#  'katherine',
#  'huarmey',
#  'wanlaweyn',
#  'vaitape',
#  'otuzco',
#  'bengkulu',
#  'kawana waters',
#  'wulanhaote',
#  'koumac',
#  'amparafaravola',
#  'buqayq',
#  'mopti',
#  'bonaventure',
#  'tevriz',
#  'ruteng',
#  'flinders',
#  'alofi',
#  'scarborough',
#  'sao joao da barra',
#  'new smyrna beach',
#  'magistralnyy',
#  'fairbanks',
#  'kahului',
#  'stornoway',
#  'rocha',
#  'tchollire',
#  'norman wells',
#  'canutama',
#  'hun',
#  'miami',
#  'carlow',
#  'white rock',
#  'ulaangom',
#  'rakovski',
#  'nyurba',
#  'port macquarie',
#  'hareid',
#  'turukhansk',
#  'tartagal',
#  'bargal',
#  'gamba',
#  'notse',
#  'khani',
#  'huilong',
#  'lydenburg',
#  'porangatu',
#  'bosaso',
#  'edgewater',
#  'los llanos de aridane',
#  'marienburg',
#  'ishigaki',
#  'gizo',
#  'karwar',
#  'emerald',
#  'rorvik',
#  'hofn',
#  'kirakira',
#  'tonj',
#  'shumskiy',
#  'zhigansk',
#  'batagay-alyta',
#  'cocobeach',
#  'ilulissat',
#  'marsa matruh',
#  'xai-xai',
#  'mazyr',
#  'santa rosalia',
#  'ratnagiri',
#  'ambanja',
#  'sobolevo',
#  'makuyuni',
#  'ekhabi',
#  'mabaruma',
#  'alyangula',
#  'senneterre',
#  'matara',
#  'deputatskiy',
#  'popova',
#  'tessalit',
#  'narbonne',
#  'antalaha',
#  'faya',
#  'idenao',
#  'cognac',
#  'okhotsk',
#  'attawapiskat',
#  'kochi',
#  'praia',
#  'vyshneve',
#  'valle de allende',
#  'sorvag',
#  'sao filipe',
#  'acarau',
#  'moron',
#  'jhalawar',
#  'hoa binh',
#  'dubrovka',
#  'sentyabrskiy',
#  'gazipur',
#  'san jose de guanipa',
#  'poum',
#  'itarema',
#  'cepu',
#  'guatire',
#  'kalmunai',
#  'samarai',
#  'adilcevaz',
#  'akyab',
#  'orikum',
#  'ayorou',
#  'constitucion',
#  'jalu',
#  'zyryanka',
#  'la ronge',
#  'touros',
#  'road town',
#  'machalpur',
#  'boende',
#  'abha',
#  'victoria',
#  'sinnamary',
#  'peniche',
#  'necochea',
#  'ciudad bolivar',
#  'honningsvag',
#  'gwadar',
#  'otradinskiy',
#  'grindavik',
#  'katsuura',
#  'oyama',
#  'san luis de palenque',
#  'pacific grove',
#  'kitimat',
#  'buraydah',
#  'troitskoye',
#  'geraldton',
#  'rio rancho',
#  'baykit',
#  'asyut',
#  'san vicente de canete',
#  'havoysund',
#  'mama',
#  'inhambane',
#  'karauzyak',
#  'vao',
#  'valdosta',
#  'sorland',
#  'bhadrachalam',
#  'ocos',
#  'ulladulla',
#  'kulunda',
#  'sistranda',
#  'lulea',
#  'mahibadhoo',
#  'cherskiy',
#  'koroni',
#  'mirabad',
#  'tondano',
#  'cuernavaca',
#  'regeneracao',
#  'mount isa',
#  'den helder',
#  'fagetelu',
#  'sandpoint',
#  'mpulungu',
#  'grants pass',
#  'the valley',
#  'palmer',
#  'araouane',
#  'port hedland',
#  'safaga',
#  'kamaishi',
#  'talnakh',
#  'makakilo city',
#  'carndonagh',
#  'tsarychanka',
#  'guerrero negro',
#  'rawson',
#  'sergeyevka',
#  'umm durman',
#  'eyl',
#  'tahoua',
#  'takoradi',
#  'laranjal paulista',
#  'petropavlovsk-kamchatskiy',
#  'yulara',
#  'sardarshahr',
#  'yeppoon',
#  'bagrami',
#  'puqi',
#  'brisbane',
#  'tigre',
#  'pedernales',
#  'hamada',
#  'shaunavon',
#  'mporokoso',
#  'lavrentiya',
#  'papara',
#  'develi',
#  'lieksa',
#  'vicksburg',
#  'usinsk',
#  'olafsvik',
#  'bhatkal',
#  'sola',
#  'fernie',
#  'caravelas',
#  'beloha',
#  'hovd',
#  'castelldefels',
#  'aykhal',
#  'jumla',
#  'imbituba',
#  'salamina',
#  'kuryk',
#  'gualaceo',
#  'albion',
#  'paamiut',
#  'banda aceh',
#  'poronaysk',
#  'nhamunda',
#  'buzmeyin',
#  'catamarca',
#  'xining',
#  'karaman',
#  'karratha',
#  'berlevag',
#  'kota kinabalu',
#  'grand gaube',
#  'ulcinj',
#  'pemangkat',
#  'lofthus',
#  'darnah',
#  'xuanhua',
#  'baykalsk',
#  'broome',
#  'sarkand',
#  'apatou',
#  'pergamino',
#  'koshurnikovo',
#  'qaqortoq',
#  'richards bay',
#  'sinjah',
#  'miramar',
#  'draguignan',
#  'hamilton',
#  'mumford',
#  'goderich',
#  'cassia',
#  'maple creek',
#  'vila',
#  'sarangani',
#  'kuytun',
#  'zima',
#  'strelka',
#  'quthing',
#  'senekal',
#  'santa fe',
#  'leninsk-kuznetskiy',
#  'sambava',
#  'altamira',
#  'lazaro cardenas',
#  'pochutla',
#  'talara',
#  'amderma',
#  'atotonilco el grande',
#  'luis correia',
#  'takab',
#  'nouadhibou',
#  'balaipungut',
#  'charlestown',
#  'muroto',
#  'nyimba',
#  'kavaratti',
#  'jardim',
#  'rawannawi',
#  'joao pessoa',
#  'rio negrinho',
#  'bredy',
#  'bressuire',
#  'andreapol',
#  'utiroa',
#  'ati',
#  'bang saphan',
#  'amalapuram',
#  'libourne',
#  'san andres',
#  'viligili',
#  'bobrovka',
#  'samusu',
#  'ixtapa',
#  'elliot lake',
#  'coquimbo',
#  'novobirilyussy',
#  'cairns',
#  'mount holly',
#  'karoi',
#  'revelstoke',
#  'tecoanapa',
#  'kutum',
#  'mandalgovi',
#  'carutapera',
#  'ballina',
#  'kilindoni',
#  'torrevieja',
#  'dunedin',
#  'amzya',
#  'kaeo',
#  'nalut',
#  'barawe',
#  'ust-nera',
#  'kieta',
#  'marcona',
#  'balabac',
#  'dickinson',
#  'cantapoy',
#  'college',
#  'hope',
#  'semnan',
#  'puerto ayacucho',
#  'atbasar',
#  'monki',
#  'karaul',
#  'marzuq',
#  'henties bay',
#  'aberystwyth',
#  'carlisle',
#  'rungata',
#  'padang',
#  'ketchikan',
#  'matay',
#  'arman',
#  'bilgoraj',
#  'abalak',
#  'kruisfontein',
#  'pitimbu',
#  'surt',
#  'adrar',
#  'bridlington',
#  'zhovtneve',
#  'vestmannaeyjar',
#  'teya',
#  'shenjiamen',
#  'isiro',
#  'nampula',
#  'meadow lake',
#  'san cristobal',
#  'abrau-dyurso',
#  'hualmay',
#  'ambovombe',
#  'san antonio',
#  'tadine',
#  'bonthe',
#  'alta floresta',
#  'ryotsu',
#  'ponta delgada',
#  'virginia beach',
#  'ada',
#  'warrensburg',
#  'morehead',
#  'rio gallegos',
#  'san jose',
#  'bay roberts',
#  'umzimvubu',
#  'san bartolome de tirajana',
#  'cermik',
#  'nykobing',
#  'anori',
#  'san patricio',
#  'luwuk',
#  'correntina',
#  'yamethin',
#  'vila velha',
#  'mehamn',
#  'tara',
#  'agogo',
#  'fare',
#  'igrim',
#  'putina',
#  'san lawrenz',
#  'warrnambool',
#  'owasso',
#  'belene',
#  'ngunguru',
#  'cabinda',
#  'vicuna',
#  'mae ramat',
#  'bimbo',
#  'puerto gaitan',
#  'muisne',
#  'neiafu',
#  'yanan',
#  'chitungwiza',
#  'baoshan',
#  'comodoro rivadavia',
#  'silver city',
#  'yarmouth',
#  'san matias',
#  'ust-kulom',
#  'strezhevoy',
#  'inongo',
#  'aitape',
#  'harnosand',
#  'dauphin',
#  'zeya',
#  'parnamirim',
#  'leua',
#  'bara',
#  'broken hill',
#  'satitoa',
#  'shimoda',
#  'santiago',
#  'atambua',
#  'eliot',
#  'bajil',
#  'halalo',
#  'porto seguro',
#  'jiuquan',
#  'veraval',
#  'svetlogorsk',
#  'rosarito',
#  'flin flon',
#  'tateyama',
#  'tiznit']

# %%
# Create a url for API call

url = "https://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=" + weather_api_key

# %%
# Make an API call to get current weather data for each city

city_data = []

print("Beginning Data Retrieval     ")

print("-----------------------------")

record_count = 1

set_count = 1

for i, city in enumerate(cities):
    
    if (i % 50 == 0 and i >= 50):
        
        set_count += 1
        
        record_count = 1
        
        time.sleep(60)
        
    city_url = url + "&q=" + city.replace(" ", "+")
    
    print(f"Processing {record_count} of Set {set_count} | {city}")
    
    record_count += 1
    
    try:
        
        city_weather = requests.get(city_url).json()
        
        city_lat = city_weather['coord']['lat']
        
        city_lng = city_weather['coord']['lon']
        
        city_max_temp = city_weather['main']['temp_max']
        
        city_humidity = city_weather['main']['humidity']
        
        city_clouds = city_weather['clouds']['all']
        
        city_wind = city_weather['wind']['speed']
        
        city_country = city_weather['sys']['country']
        
        city_description = city_weather['weather'][0]['description']
        
        city_data.append({"City": city.title(),
                         
                          "Country": city_country,
                          
                          "Lat": city_lat,
                          
                          "Lng": city_lng,
                          
                          "Max Temp": city_max_temp,
                          
                          "Humidity": city_humidity,
                          
                          "Cloudiness": city_clouds,
                          
                          "Wind Speed": city_wind,
                          
                          "Current Description": city_description})
        
    except:
            
        print("City not found. Skipping...")
            
print("-----------------------------")

print("Data Retrieval Complete")

print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing 1 of Set 1 | meyungs
# City not found. Skipping...
# Processing 2 of Set 1 | fuerte olimpo
# Processing 3 of Set 1 | barrow
# Processing 4 of Set 1 | rikitea
# Processing 5 of Set 1 | kodiak
# Processing 6 of Set 1 | verkhoyansk
# Processing 7 of Set 1 | vaitupu
# City not found. Skipping...
# Processing 8 of Set 1 | hermanus
# Processing 9 of Set 1 | bluff
# Processing 10 of Set 1 | margate
# Processing 11 of Set 1 | skagastrond
# City not found. Skipping...
# Processing 12 of Set 1 | taolanaro
# City not found. Skipping...
# Processing 13 of Set 1 | provideniya
# Processing 14 of Set 1 | pangnirtung
# Processing 15 of Set 1 | punta arenas
# Processing 16 of Set 1 | carnarvon
# Processing 17 of Set 1 | east london
# Processing 18 of Set 1 | ugoofaaru
# Processing 19 of Set 1 | vaini
# Processing 20 of Set 1 | celestun
# Processing 21 of Set 1 | hithadhoo
# Processing 22 of Set 1 | tiksi
# Processing 23 of Set 1 | galveston
# Processing 24 of Set 1 | formosa do rio preto
# Processing 25 of Set 1 | aksarka
# Processing 26 of Set 1 | bredasdorp
# Processing 27 of Set 1 | yamada
# Processing 28 of Set 1 | ushuaia
# Processing 29 of Set 1 | sayat
# Processing 30 of Set 1 | kavieng
# Processing 31 of Set 1 | mandurah
# Processing 32 of Set 1 | belushya guba
# City not found. Skipping...
# Processing 33 of Set 1 | ormara
# Processing 34 of Set 1 | upernavik
# Processing 35 of Set 1 | port lincoln
# Processing 36 of Set 1 | nikolskoye
# Processing 37 of Set 1 | kapaa
# Processing 38 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing 39 of Set 1 | new norfolk
# Processing 40 of Set 1 | hasaki
# Processing 41 of Set 1 | yatou
# Processing 42 of Set 1 | buala
# Processing 43 of Set 1 | palabuhanratu
# City not found. Skipping...
# Processing 44 of Set 1 | chokurdakh
# Processing 45 of Set 1 | avarua
# Processing 46 of Set 1 | marawi
# Processing 47 of Set 1 | sangmelima
# Processing 48 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing 49 of Set 1 | lompoc
# Processing 50 of Set 1 | san carlos de bariloche
# Processing 1 of Set 2 | dikson
# Processing 2 of Set 2 | frontera hidalgo
# Processing 3 of Set 2 | busselton
# Processing 4 of Set 2 | kharp
# Processing 5 of Set 2 | grand river south east
# City not found. Skipping...
# Processing 6 of Set 2 | puerto ayora
# Processing 7 of Set 2 | port elizabeth
# Processing 8 of Set 2 | ribeira grande
# Processing 9 of Set 2 | faanui
# Processing 10 of Set 2 | bolungarvik
# City not found. Skipping...
# Processing 11 of Set 2 | saint george
# Processing 12 of Set 2 | barentsburg
# City not found. Skipping...
# Processing 13 of Set 2 | mataura
# Processing 14 of Set 2 | qaanaaq
# Processing 15 of Set 2 | atuona
# Processing 16 of Set 2 | longyearbyen
# Processing 17 of Set 2 | nome
# Processing 18 of Set 2 | ponta do sol
# Processing 19 of Set 2 | souillac
# Processing 20 of Set 2 | borogontsy
# Processing 21 of Set 2 | cidreira
# Processing 22 of Set 2 | coahuayana
# Processing 23 of Set 2 | mbandaka
# Processing 24 of Set 2 | albany
# Processing 25 of Set 2 | dingle
# Processing 26 of Set 2 | champerico
# Processing 27 of Set 2 | saskylakh
# Processing 28 of Set 2 | clarksburg
# Processing 29 of Set 2 | samalaeulu
# City not found. Skipping...
# Processing 30 of Set 2 | balakhninskiy
# Processing 31 of Set 2 | sur
# Processing 32 of Set 2 | atlantic beach
# Processing 33 of Set 2 | hobyo
# Processing 34 of Set 2 | tuktoyaktuk
# Processing 35 of Set 2 | sisimiut
# Processing 36 of Set 2 | nguiu
# City not found. Skipping...
# Processing 37 of Set 2 | price
# Processing 38 of Set 2 | khatanga
# Processing 39 of Set 2 | victor harbor
# Processing 40 of Set 2 | tsogni
# Processing 41 of Set 2 | ust-maya
# Processing 42 of Set 2 | tigil
# Processing 43 of Set 2 | takestan
# Processing 44 of Set 2 | jamestown
# Processing 45 of Set 2 | mugur-aksy
# Processing 46 of Set 2 | kang
# Processing 47 of Set 2 | chuy
# Processing 48 of Set 2 | mariano escobedo
# Processing 49 of Set 2 | port hardy
# Processing 50 of Set 2 | saint-augustin
# Processing 1 of Set 3 | krasnoselkup
# Processing 2 of Set 3 | bandarbeyla
# Processing 3 of Set 3 | bethel
# Processing 4 of Set 3 | ostrovnoy
# Processing 5 of Set 3 | castro
# Processing 6 of Set 3 | luderitz
# Processing 7 of Set 3 | neon karlovasion
# Processing 8 of Set 3 | kaitangata
# Processing 9 of Set 3 | mahebourg
# Processing 10 of Set 3 | khartoum
# Processing 11 of Set 3 | betare oya
# Processing 12 of Set 3 | houma
# Processing 13 of Set 3 | bairiki
# Processing 14 of Set 3 | keningau
# Processing 15 of Set 3 | klaksvik
# Processing 16 of Set 3 | moose factory
# Processing 17 of Set 3 | ararat
# Processing 18 of Set 3 | culebra
# Processing 19 of Set 3 | tsihombe
# City not found. Skipping...
# Processing 20 of Set 3 | hobart
# Processing 21 of Set 3 | leopold
# Processing 22 of Set 3 | port alfred
# Processing 23 of Set 3 | mrirt
# City not found. Skipping...
# Processing 24 of Set 3 | berezovyy
# Processing 25 of Set 3 | erenhot
# Processing 26 of Set 3 | la romana
# Processing 27 of Set 3 | hilo
# Processing 28 of Set 3 | terrak
# Processing 29 of Set 3 | rock sound
# Processing 30 of Set 3 | canon city
# Processing 31 of Set 3 | ziarat
# Processing 32 of Set 3 | agadez
# Processing 33 of Set 3 | zheleznodorozhnyy
# Processing 34 of Set 3 | aklavik
# Processing 35 of Set 3 | bangassou
# Processing 36 of Set 3 | cape town
# Processing 37 of Set 3 | westport
# Processing 38 of Set 3 | modakeke
# Processing 39 of Set 3 | kimbe
# Processing 40 of Set 3 | tautira
# Processing 41 of Set 3 | saint anthony
# Processing 42 of Set 3 | tasiilaq
# Processing 43 of Set 3 | aden
# Processing 44 of Set 3 | merthyr tydfil
# Processing 45 of Set 3 | tomatlan
# Processing 46 of Set 3 | te anau
# Processing 47 of Set 3 | lagoa
# Processing 48 of Set 3 | lethem
# Processing 49 of Set 3 | namatanai
# Processing 50 of Set 3 | inirida
# Processing 1 of Set 4 | esperance
# Processing 2 of Set 4 | severo-kurilsk
# Processing 3 of Set 4 | lichinga
# Processing 4 of Set 4 | lebu
# Processing 5 of Set 4 | padron
# Processing 6 of Set 4 | saint-georges
# Processing 7 of Set 4 | ayan
# Processing 8 of Set 4 | salalah
# Processing 9 of Set 4 | nioro
# Processing 10 of Set 4 | port-gentil
# Processing 11 of Set 4 | rio de janeiro
# Processing 12 of Set 4 | kallithea
# Processing 13 of Set 4 | georgetown
# Processing 14 of Set 4 | kamenskoye
# City not found. Skipping...
# Processing 15 of Set 4 | fortuna
# Processing 16 of Set 4 | presidencia roque saenz pena
# Processing 17 of Set 4 | cumaribo
# City not found. Skipping...
# Processing 18 of Set 4 | magadan
# Processing 19 of Set 4 | husavik
# Processing 20 of Set 4 | tambura
# Processing 21 of Set 4 | brae
# Processing 22 of Set 4 | port hawkesbury
# Processing 23 of Set 4 | antofagasta
# Processing 24 of Set 4 | saldanha
# Processing 25 of Set 4 | garowe
# Processing 26 of Set 4 | banmo
# City not found. Skipping...
# Processing 27 of Set 4 | zarichne
# Processing 28 of Set 4 | port blair
# Processing 29 of Set 4 | stepnogorsk
# Processing 30 of Set 4 | sitka
# Processing 31 of Set 4 | iquique
# Processing 32 of Set 4 | merauke
# Processing 33 of Set 4 | atar
# Processing 34 of Set 4 | meulaboh
# Processing 35 of Set 4 | kloulklubed
# Processing 36 of Set 4 | butaritari
# Processing 37 of Set 4 | srednekolymsk
# Processing 38 of Set 4 | mar del plata
# Processing 39 of Set 4 | maniitsoq
# Processing 40 of Set 4 | rundu
# Processing 41 of Set 4 | lyubim
# Processing 42 of Set 4 | nuuk
# Processing 43 of Set 4 | axim
# Processing 44 of Set 4 | cururupu
# Processing 45 of Set 4 | along
# Processing 46 of Set 4 | tumannyy
# City not found. Skipping...
# Processing 47 of Set 4 | socorro
# Processing 48 of Set 4 | iracoubo
# Processing 49 of Set 4 | narsaq
# Processing 50 of Set 4 | urusha
# Processing 1 of Set 5 | tawnat
# City not found. Skipping...
# Processing 2 of Set 5 | alekseyevka
# Processing 3 of Set 5 | naze
# Processing 4 of Set 5 | vila franca do campo
# Processing 5 of Set 5 | mersing
# Processing 6 of Set 5 | makushino
# Processing 7 of Set 5 | haines junction
# Processing 8 of Set 5 | balkhash
# Processing 9 of Set 5 | ancud
# Processing 10 of Set 5 | nemuro
# Processing 11 of Set 5 | mingshui
# Processing 12 of Set 5 | abu samrah
# Processing 13 of Set 5 | westpunt
# City not found. Skipping...
# Processing 14 of Set 5 | taltal
# Processing 15 of Set 5 | coihaique
# Processing 16 of Set 5 | oistins
# Processing 17 of Set 5 | clarence town
# Processing 18 of Set 5 | sao gabriel da cachoeira
# Processing 19 of Set 5 | jibuti
# Processing 20 of Set 5 | hami
# Processing 21 of Set 5 | mitzic
# Processing 22 of Set 5 | lasa
# Processing 23 of Set 5 | lorengau
# Processing 24 of Set 5 | nouakchott
# Processing 25 of Set 5 | saleaula
# City not found. Skipping...
# Processing 26 of Set 5 | lucea
# Processing 27 of Set 5 | qabis
# City not found. Skipping...
# Processing 28 of Set 5 | pacora
# Processing 29 of Set 5 | iskateley
# Processing 30 of Set 5 | robertsport
# Processing 31 of Set 5 | bintulu
# Processing 32 of Set 5 | marinette
# Processing 33 of Set 5 | hervey bay
# Processing 34 of Set 5 | isangel
# Processing 35 of Set 5 | lata
# Processing 36 of Set 5 | iqaluit
# Processing 37 of Set 5 | abu kamal
# Processing 38 of Set 5 | thompson
# Processing 39 of Set 5 | belaya gora
# Processing 40 of Set 5 | naryan-mar
# Processing 41 of Set 5 | khipro
# Processing 42 of Set 5 | sahrak
# City not found. Skipping...
# Processing 43 of Set 5 | pizhma
# Processing 44 of Set 5 | adre
# Processing 45 of Set 5 | cabo san lucas
# Processing 46 of Set 5 | arraial do cabo
# Processing 47 of Set 5 | pevek
# Processing 48 of Set 5 | shubarshi
# Processing 49 of Set 5 | hihifo
# City not found. Skipping...
# Processing 50 of Set 5 | saint-pierre
# Processing 1 of Set 6 | mys shmidta
# City not found. Skipping...
# Processing 2 of Set 6 | gilgit
# Processing 3 of Set 6 | yerbogachen
# Processing 4 of Set 6 | hare bay
# Processing 5 of Set 6 | ahipara
# Processing 6 of Set 6 | clyde river
# Processing 7 of Set 6 | hay river
# Processing 8 of Set 6 | togur
# Processing 9 of Set 6 | airai
# Processing 10 of Set 6 | arrifes
# Processing 11 of Set 6 | grand centre
# City not found. Skipping...
# Processing 12 of Set 6 | san policarpo
# Processing 13 of Set 6 | oga
# Processing 14 of Set 6 | genhe
# Processing 15 of Set 6 | codrington
# Processing 16 of Set 6 | mattru
# Processing 17 of Set 6 | taranagar
# Processing 18 of Set 6 | katangli
# Processing 19 of Set 6 | otradnoye
# Processing 20 of Set 6 | tura
# Processing 21 of Set 6 | skibbereen
# Processing 22 of Set 6 | bambous virieux
# Processing 23 of Set 6 | fukue
# Processing 24 of Set 6 | pisco
# Processing 25 of Set 6 | mosetse
# Processing 26 of Set 6 | batemans bay
# Processing 27 of Set 6 | bilma
# Processing 28 of Set 6 | marrakesh
# Processing 29 of Set 6 | tarko-sale
# Processing 30 of Set 6 | tuatapere
# Processing 31 of Set 6 | areosa
# Processing 32 of Set 6 | benghazi
# Processing 33 of Set 6 | ust-kamchatsk
# City not found. Skipping...
# Processing 34 of Set 6 | temaraia
# City not found. Skipping...
# Processing 35 of Set 6 | cheuskiny
# City not found. Skipping...
# Processing 36 of Set 6 | kadykchan
# City not found. Skipping...
# Processing 37 of Set 6 | morant bay
# Processing 38 of Set 6 | letka
# Processing 39 of Set 6 | katobu
# Processing 40 of Set 6 | torbay
# Processing 41 of Set 6 | jinchengjiang
# City not found. Skipping...
# Processing 42 of Set 6 | namibe
# Processing 43 of Set 6 | mayo
# Processing 44 of Set 6 | chino
# Processing 45 of Set 6 | hunsur
# Processing 46 of Set 6 | fort saint john
# City not found. Skipping...
# Processing 47 of Set 6 | hobbs
# Processing 48 of Set 6 | asfi
# Processing 49 of Set 6 | barbate
# Processing 50 of Set 6 | dargaville
# Processing 1 of Set 7 | ambon
# Processing 2 of Set 7 | lannion
# Processing 3 of Set 7 | vanersborg
# Processing 4 of Set 7 | leningradskiy
# Processing 5 of Set 7 | raymondville
# Processing 6 of Set 7 | sorong
# Processing 7 of Set 7 | korla
# Processing 8 of Set 7 | asau
# Processing 9 of Set 7 | zhengjiatun
# Processing 10 of Set 7 | klyuchi
# Processing 11 of Set 7 | saint-philippe
# Processing 12 of Set 7 | lugovoy
# Processing 13 of Set 7 | yellowknife
# Processing 14 of Set 7 | tam ky
# Processing 15 of Set 7 | samfya
# Processing 16 of Set 7 | novo aripuana
# Processing 17 of Set 7 | jati
# Processing 18 of Set 7 | najran
# Processing 19 of Set 7 | penzance
# Processing 20 of Set 7 | ypsonas
# Processing 21 of Set 7 | nishihara
# Processing 22 of Set 7 | nanortalik
# Processing 23 of Set 7 | maumere
# Processing 24 of Set 7 | kalomo
# City not found. Skipping...
# Processing 25 of Set 7 | katherine
# Processing 26 of Set 7 | huarmey
# Processing 27 of Set 7 | wanlaweyn
# Processing 28 of Set 7 | vaitape
# Processing 29 of Set 7 | otuzco
# Processing 30 of Set 7 | bengkulu
# Processing 31 of Set 7 | kawana waters
# City not found. Skipping...
# Processing 32 of Set 7 | wulanhaote
# City not found. Skipping...
# Processing 33 of Set 7 | koumac
# Processing 34 of Set 7 | amparafaravola
# Processing 35 of Set 7 | buqayq
# City not found. Skipping...
# Processing 36 of Set 7 | mopti
# Processing 37 of Set 7 | bonaventure
# Processing 38 of Set 7 | tevriz
# Processing 39 of Set 7 | ruteng
# Processing 40 of Set 7 | flinders
# Processing 41 of Set 7 | alofi
# Processing 42 of Set 7 | scarborough
# Processing 43 of Set 7 | sao joao da barra
# Processing 44 of Set 7 | new smyrna beach
# Processing 45 of Set 7 | magistralnyy
# Processing 46 of Set 7 | fairbanks
# Processing 47 of Set 7 | kahului
# Processing 48 of Set 7 | stornoway
# Processing 49 of Set 7 | rocha
# Processing 50 of Set 7 | tchollire
# Processing 1 of Set 8 | norman wells
# Processing 2 of Set 8 | canutama
# Processing 3 of Set 8 | hun
# Processing 4 of Set 8 | miami
# Processing 5 of Set 8 | carlow
# Processing 6 of Set 8 | white rock
# Processing 7 of Set 8 | ulaangom
# Processing 8 of Set 8 | rakovski
# Processing 9 of Set 8 | nyurba
# Processing 10 of Set 8 | port macquarie
# Processing 11 of Set 8 | hareid
# Processing 12 of Set 8 | turukhansk
# Processing 13 of Set 8 | tartagal
# Processing 14 of Set 8 | bargal
# City not found. Skipping...
# Processing 15 of Set 8 | gamba
# Processing 16 of Set 8 | notse
# Processing 17 of Set 8 | khani
# Processing 18 of Set 8 | huilong
# Processing 19 of Set 8 | lydenburg
# Processing 20 of Set 8 | porangatu
# Processing 21 of Set 8 | bosaso
# Processing 22 of Set 8 | edgewater
# Processing 23 of Set 8 | los llanos de aridane
# Processing 24 of Set 8 | marienburg
# Processing 25 of Set 8 | ishigaki
# Processing 26 of Set 8 | gizo
# Processing 27 of Set 8 | karwar
# Processing 28 of Set 8 | emerald
# Processing 29 of Set 8 | rorvik
# Processing 30 of Set 8 | hofn
# Processing 31 of Set 8 | kirakira
# Processing 32 of Set 8 | tonj
# Processing 33 of Set 8 | shumskiy
# Processing 34 of Set 8 | zhigansk
# Processing 35 of Set 8 | batagay-alyta
# Processing 36 of Set 8 | cocobeach
# Processing 37 of Set 8 | ilulissat
# Processing 38 of Set 8 | marsa matruh
# Processing 39 of Set 8 | xai-xai
# Processing 40 of Set 8 | mazyr
# Processing 41 of Set 8 | santa rosalia
# Processing 42 of Set 8 | ratnagiri
# Processing 43 of Set 8 | ambanja
# Processing 44 of Set 8 | sobolevo
# Processing 45 of Set 8 | makuyuni
# Processing 46 of Set 8 | ekhabi
# Processing 47 of Set 8 | mabaruma
# Processing 48 of Set 8 | alyangula
# Processing 49 of Set 8 | senneterre
# Processing 50 of Set 8 | matara
# Processing 1 of Set 9 | deputatskiy
# Processing 2 of Set 9 | popova
# Processing 3 of Set 9 | tessalit
# Processing 4 of Set 9 | narbonne
# Processing 5 of Set 9 | antalaha
# Processing 6 of Set 9 | faya
# Processing 7 of Set 9 | idenao
# Processing 8 of Set 9 | cognac
# Processing 9 of Set 9 | okhotsk
# Processing 10 of Set 9 | attawapiskat
# City not found. Skipping...
# Processing 11 of Set 9 | kochi
# Processing 12 of Set 9 | praia
# Processing 13 of Set 9 | vyshneve
# Processing 14 of Set 9 | valle de allende
# Processing 15 of Set 9 | sorvag
# City not found. Skipping...
# Processing 16 of Set 9 | sao filipe
# Processing 17 of Set 9 | acarau
# Processing 18 of Set 9 | moron
# Processing 19 of Set 9 | jhalawar
# Processing 20 of Set 9 | hoa binh
# Processing 21 of Set 9 | dubrovka
# Processing 22 of Set 9 | sentyabrskiy
# City not found. Skipping...
# Processing 23 of Set 9 | gazipur
# Processing 24 of Set 9 | san jose de guanipa
# Processing 25 of Set 9 | poum
# Processing 26 of Set 9 | itarema
# Processing 27 of Set 9 | cepu
# Processing 28 of Set 9 | guatire
# Processing 29 of Set 9 | kalmunai
# Processing 30 of Set 9 | samarai
# Processing 31 of Set 9 | adilcevaz
# Processing 32 of Set 9 | akyab
# Processing 33 of Set 9 | orikum
# Processing 34 of Set 9 | ayorou
# Processing 35 of Set 9 | constitucion
# Processing 36 of Set 9 | jalu
# Processing 37 of Set 9 | zyryanka
# Processing 38 of Set 9 | la ronge
# Processing 39 of Set 9 | touros
# Processing 40 of Set 9 | road town
# Processing 41 of Set 9 | machalpur
# Processing 42 of Set 9 | boende
# Processing 43 of Set 9 | abha
# Processing 44 of Set 9 | victoria
# Processing 45 of Set 9 | sinnamary
# Processing 46 of Set 9 | peniche
# Processing 47 of Set 9 | necochea
# Processing 48 of Set 9 | ciudad bolivar
# Processing 49 of Set 9 | honningsvag
# Processing 50 of Set 9 | gwadar
# Processing 1 of Set 10 | otradinskiy
# City not found. Skipping...
# Processing 2 of Set 10 | grindavik
# Processing 3 of Set 10 | katsuura
# Processing 4 of Set 10 | oyama
# Processing 5 of Set 10 | san luis de palenque
# Processing 6 of Set 10 | pacific grove
# Processing 7 of Set 10 | kitimat
# Processing 8 of Set 10 | buraydah
# Processing 9 of Set 10 | troitskoye
# Processing 10 of Set 10 | geraldton
# Processing 11 of Set 10 | rio rancho
# Processing 12 of Set 10 | baykit
# Processing 13 of Set 10 | asyut
# Processing 14 of Set 10 | san vicente de canete
# Processing 15 of Set 10 | havoysund
# Processing 16 of Set 10 | mama
# Processing 17 of Set 10 | inhambane
# Processing 18 of Set 10 | karauzyak
# City not found. Skipping...
# Processing 19 of Set 10 | vao
# Processing 20 of Set 10 | valdosta
# Processing 21 of Set 10 | sorland
# Processing 22 of Set 10 | bhadrachalam
# Processing 23 of Set 10 | ocos
# Processing 24 of Set 10 | ulladulla
# Processing 25 of Set 10 | kulunda
# Processing 26 of Set 10 | sistranda
# Processing 27 of Set 10 | lulea
# Processing 28 of Set 10 | mahibadhoo
# Processing 29 of Set 10 | cherskiy
# Processing 30 of Set 10 | koroni
# Processing 31 of Set 10 | mirabad
# Processing 32 of Set 10 | tondano
# Processing 33 of Set 10 | cuernavaca
# Processing 34 of Set 10 | regeneracao
# Processing 35 of Set 10 | mount isa
# Processing 36 of Set 10 | den helder
# Processing 37 of Set 10 | fagetelu
# Processing 38 of Set 10 | sandpoint
# Processing 39 of Set 10 | mpulungu
# Processing 40 of Set 10 | grants pass
# Processing 41 of Set 10 | the valley
# Processing 42 of Set 10 | palmer
# Processing 43 of Set 10 | araouane
# Processing 44 of Set 10 | port hedland
# Processing 45 of Set 10 | safaga
# Processing 46 of Set 10 | kamaishi
# Processing 47 of Set 10 | talnakh
# Processing 48 of Set 10 | makakilo city
# Processing 49 of Set 10 | carndonagh
# Processing 50 of Set 10 | tsarychanka
# Processing 1 of Set 11 | guerrero negro
# Processing 2 of Set 11 | rawson
# Processing 3 of Set 11 | sergeyevka
# Processing 4 of Set 11 | umm durman
# City not found. Skipping...
# Processing 5 of Set 11 | eyl
# Processing 6 of Set 11 | tahoua
# Processing 7 of Set 11 | takoradi
# Processing 8 of Set 11 | laranjal paulista
# Processing 9 of Set 11 | petropavlovsk-kamchatskiy
# Processing 10 of Set 11 | yulara
# Processing 11 of Set 11 | sardarshahr
# Processing 12 of Set 11 | yeppoon
# Processing 13 of Set 11 | bagrami
# Processing 14 of Set 11 | puqi
# Processing 15 of Set 11 | brisbane
# Processing 16 of Set 11 | tigre
# Processing 17 of Set 11 | pedernales
# Processing 18 of Set 11 | hamada
# Processing 19 of Set 11 | shaunavon
# Processing 20 of Set 11 | mporokoso
# Processing 21 of Set 11 | lavrentiya
# Processing 22 of Set 11 | papara
# Processing 23 of Set 11 | develi
# Processing 24 of Set 11 | lieksa
# Processing 25 of Set 11 | vicksburg
# Processing 26 of Set 11 | usinsk
# Processing 27 of Set 11 | olafsvik
# Processing 28 of Set 11 | bhatkal
# Processing 29 of Set 11 | sola
# Processing 30 of Set 11 | fernie
# Processing 31 of Set 11 | caravelas
# Processing 32 of Set 11 | beloha
# Processing 33 of Set 11 | hovd
# Processing 34 of Set 11 | castelldefels
# Processing 35 of Set 11 | aykhal
# Processing 36 of Set 11 | jumla
# Processing 37 of Set 11 | imbituba
# Processing 38 of Set 11 | salamina
# Processing 39 of Set 11 | kuryk
# Processing 40 of Set 11 | gualaceo
# Processing 41 of Set 11 | albion
# Processing 42 of Set 11 | paamiut
# Processing 43 of Set 11 | banda aceh
# Processing 44 of Set 11 | poronaysk
# Processing 45 of Set 11 | nhamunda
# Processing 46 of Set 11 | buzmeyin
# Processing 47 of Set 11 | catamarca
# Processing 48 of Set 11 | xining
# Processing 49 of Set 11 | karaman
# Processing 50 of Set 11 | karratha
# Processing 1 of Set 12 | berlevag
# Processing 2 of Set 12 | kota kinabalu
# Processing 3 of Set 12 | grand gaube
# Processing 4 of Set 12 | ulcinj
# Processing 5 of Set 12 | pemangkat
# Processing 6 of Set 12 | lofthus
# Processing 7 of Set 12 | darnah
# Processing 8 of Set 12 | xuanhua
# Processing 9 of Set 12 | baykalsk
# Processing 10 of Set 12 | broome
# Processing 11 of Set 12 | sarkand
# Processing 12 of Set 12 | apatou
# Processing 13 of Set 12 | pergamino
# Processing 14 of Set 12 | koshurnikovo
# Processing 15 of Set 12 | qaqortoq
# Processing 16 of Set 12 | richards bay
# Processing 17 of Set 12 | sinjah
# City not found. Skipping...
# Processing 18 of Set 12 | miramar
# Processing 19 of Set 12 | draguignan
# Processing 20 of Set 12 | hamilton
# Processing 21 of Set 12 | mumford
# Processing 22 of Set 12 | goderich
# Processing 23 of Set 12 | cassia
# Processing 24 of Set 12 | maple creek
# Processing 25 of Set 12 | vila
# Processing 26 of Set 12 | sarangani
# Processing 27 of Set 12 | kuytun
# Processing 28 of Set 12 | zima
# Processing 29 of Set 12 | strelka
# Processing 30 of Set 12 | quthing
# Processing 31 of Set 12 | senekal
# Processing 32 of Set 12 | santa fe
# Processing 33 of Set 12 | leninsk-kuznetskiy
# Processing 34 of Set 12 | sambava
# Processing 35 of Set 12 | altamira
# Processing 36 of Set 12 | lazaro cardenas
# Processing 37 of Set 12 | pochutla
# Processing 38 of Set 12 | talara
# Processing 39 of Set 12 | amderma
# City not found. Skipping...
# Processing 40 of Set 12 | atotonilco el grande
# Processing 41 of Set 12 | luis correia
# Processing 42 of Set 12 | takab
# Processing 43 of Set 12 | nouadhibou
# Processing 44 of Set 12 | balaipungut
# Processing 45 of Set 12 | charlestown
# Processing 46 of Set 12 | muroto
# Processing 47 of Set 12 | nyimba
# Processing 48 of Set 12 | kavaratti
# Processing 49 of Set 12 | jardim
# Processing 50 of Set 12 | rawannawi
# City not found. Skipping...
# Processing 1 of Set 13 | joao pessoa
# Processing 2 of Set 13 | rio negrinho
# Processing 3 of Set 13 | bredy
# Processing 4 of Set 13 | bressuire
# Processing 5 of Set 13 | andreapol
# Processing 6 of Set 13 | utiroa
# City not found. Skipping...
# Processing 7 of Set 13 | ati
# Processing 8 of Set 13 | bang saphan
# Processing 9 of Set 13 | amalapuram
# Processing 10 of Set 13 | libourne
# Processing 11 of Set 13 | san andres
# Processing 12 of Set 13 | viligili
# City not found. Skipping...
# Processing 13 of Set 13 | bobrovka
# Processing 14 of Set 13 | samusu
# City not found. Skipping...
# Processing 15 of Set 13 | ixtapa
# Processing 16 of Set 13 | elliot lake
# Processing 17 of Set 13 | coquimbo
# Processing 18 of Set 13 | novobirilyussy
# Processing 19 of Set 13 | cairns
# Processing 20 of Set 13 | mount holly
# Processing 21 of Set 13 | karoi
# Processing 22 of Set 13 | revelstoke
# Processing 23 of Set 13 | tecoanapa
# Processing 24 of Set 13 | kutum
# Processing 25 of Set 13 | mandalgovi
# Processing 26 of Set 13 | carutapera
# Processing 27 of Set 13 | ballina
# Processing 28 of Set 13 | kilindoni
# Processing 29 of Set 13 | torrevieja
# Processing 30 of Set 13 | dunedin
# Processing 31 of Set 13 | amzya
# Processing 32 of Set 13 | kaeo
# Processing 33 of Set 13 | nalut
# Processing 34 of Set 13 | barawe
# City not found. Skipping...
# Processing 35 of Set 13 | ust-nera
# Processing 36 of Set 13 | kieta
# Processing 37 of Set 13 | marcona
# City not found. Skipping...
# Processing 38 of Set 13 | balabac
# Processing 39 of Set 13 | dickinson
# Processing 40 of Set 13 | cantapoy
# Processing 41 of Set 13 | college
# Processing 42 of Set 13 | hope
# Processing 43 of Set 13 | semnan
# Processing 44 of Set 13 | puerto ayacucho
# Processing 45 of Set 13 | atbasar
# Processing 46 of Set 13 | monki
# Processing 47 of Set 13 | karaul
# City not found. Skipping...
# Processing 48 of Set 13 | marzuq
# Processing 49 of Set 13 | henties bay
# Processing 50 of Set 13 | aberystwyth
# Processing 1 of Set 14 | carlisle
# Processing 2 of Set 14 | rungata
# City not found. Skipping...
# Processing 3 of Set 14 | padang
# Processing 4 of Set 14 | ketchikan
# Processing 5 of Set 14 | matay
# Processing 6 of Set 14 | arman
# Processing 7 of Set 14 | bilgoraj
# Processing 8 of Set 14 | abalak
# Processing 9 of Set 14 | kruisfontein
# Processing 10 of Set 14 | pitimbu
# Processing 11 of Set 14 | surt
# Processing 12 of Set 14 | adrar
# Processing 13 of Set 14 | bridlington
# Processing 14 of Set 14 | zhovtneve
# Processing 15 of Set 14 | vestmannaeyjar
# Processing 16 of Set 14 | teya
# Processing 17 of Set 14 | shenjiamen
# Processing 18 of Set 14 | isiro
# Processing 19 of Set 14 | nampula
# Processing 20 of Set 14 | meadow lake
# Processing 21 of Set 14 | san cristobal
# Processing 22 of Set 14 | abrau-dyurso
# Processing 23 of Set 14 | hualmay
# Processing 24 of Set 14 | ambovombe
# Processing 25 of Set 14 | san antonio
# Processing 26 of Set 14 | tadine
# Processing 27 of Set 14 | bonthe
# Processing 28 of Set 14 | alta floresta
# Processing 29 of Set 14 | ryotsu
# Processing 30 of Set 14 | ponta delgada
# Processing 31 of Set 14 | virginia beach
# Processing 32 of Set 14 | ada
# Processing 33 of Set 14 | warrensburg
# Processing 34 of Set 14 | morehead
# Processing 35 of Set 14 | rio gallegos
# Processing 36 of Set 14 | san jose
# Processing 37 of Set 14 | bay roberts
# Processing 38 of Set 14 | umzimvubu
# City not found. Skipping...
# Processing 39 of Set 14 | san bartolome de tirajana
# Processing 40 of Set 14 | cermik
# Processing 41 of Set 14 | nykobing
# City not found. Skipping...
# Processing 42 of Set 14 | anori
# Processing 43 of Set 14 | san patricio
# Processing 44 of Set 14 | luwuk
# Processing 45 of Set 14 | correntina
# Processing 46 of Set 14 | yamethin
# Processing 47 of Set 14 | vila velha
# Processing 48 of Set 14 | mehamn
# Processing 49 of Set 14 | tara
# Processing 50 of Set 14 | agogo
# Processing 1 of Set 15 | fare
# Processing 2 of Set 15 | igrim
# Processing 3 of Set 15 | putina
# Processing 4 of Set 15 | san lawrenz
# Processing 5 of Set 15 | warrnambool
# Processing 6 of Set 15 | owasso
# Processing 7 of Set 15 | belene
# Processing 8 of Set 15 | ngunguru
# Processing 9 of Set 15 | cabinda
# Processing 10 of Set 15 | vicuna
# Processing 11 of Set 15 | mae ramat
# Processing 12 of Set 15 | bimbo
# Processing 13 of Set 15 | puerto gaitan
# Processing 14 of Set 15 | muisne
# Processing 15 of Set 15 | neiafu
# Processing 16 of Set 15 | yanan
# City not found. Skipping...
# Processing 17 of Set 15 | chitungwiza
# Processing 18 of Set 15 | baoshan
# Processing 19 of Set 15 | comodoro rivadavia
# Processing 20 of Set 15 | silver city
# Processing 21 of Set 15 | yarmouth
# Processing 22 of Set 15 | san matias
# Processing 23 of Set 15 | ust-kulom
# Processing 24 of Set 15 | strezhevoy
# Processing 25 of Set 15 | inongo
# Processing 26 of Set 15 | aitape
# Processing 27 of Set 15 | harnosand
# Processing 28 of Set 15 | dauphin
# Processing 29 of Set 15 | zeya
# Processing 30 of Set 15 | parnamirim
# Processing 31 of Set 15 | leua
# Processing 32 of Set 15 | bara
# Processing 33 of Set 15 | broken hill
# Processing 34 of Set 15 | satitoa
# City not found. Skipping...
# Processing 35 of Set 15 | shimoda
# Processing 36 of Set 15 | santiago
# Processing 37 of Set 15 | atambua
# Processing 38 of Set 15 | eliot
# Processing 39 of Set 15 | bajil
# Processing 40 of Set 15 | halalo
# City not found. Skipping...
# Processing 41 of Set 15 | porto seguro
# Processing 42 of Set 15 | jiuquan
# Processing 43 of Set 15 | veraval
# Processing 44 of Set 15 | svetlogorsk
# Processing 45 of Set 15 | rosarito
# Processing 46 of Set 15 | flin flon
# Processing 47 of Set 15 | tateyama
# Processing 48 of Set 15 | tiznit
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 689

# %%
# Convert the city data to a dataframe

city_data_df = pd.DataFrame(city_data)

city_data_df.head(10)
# Out:
#             City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Fuerte Olimpo      PY -21.0415  -57.8738     92.03        25           7
# 1         Barrow      US  71.2906 -156.7887     39.22        87          40
# 2        Rikitea      PF -23.1203 -134.9692     74.05        71           2
# 3         Kodiak      US  57.7900 -152.4072     54.91        94         100
# 4    Verkhoyansk      RU  67.5447  133.3850     72.90        71         100
# 5       Hermanus      ZA -34.4187   19.2345     59.81        63           0
# 6          Bluff      NZ -46.6000  168.3333     50.94        77          59
# 7        Margate      GB  51.3813    1.3862     73.87        51          31
# 8    Provideniya      RU  64.3833 -173.3000     47.80        84          98
# 9    Pangnirtung      CA  66.1451  -65.7125     50.00        71          75
#
#    Wind Speed Current Description
# 0       12.80           clear sky
# 1        9.22               smoke
# 2        4.18           clear sky
# 3        3.44          light rain
# 4       12.59     overcast clouds
# 5        4.27           clear sky
# 6       21.00       broken clouds
# 7        5.01    scattered clouds
# 8        2.80     overcast clouds
# 9       10.36       broken clouds

# %%
city_data_file = "WeatherPy_Database.csv"

city_data_df.to_csv(city_data_file, index_label="City_ID")
